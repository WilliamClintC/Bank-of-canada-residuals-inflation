# %%
import pandas as pd

# Replace 'data.csv' with your CSV file's name and path
csv_file = "18100004.csv"

# Load the CSV file into a DataFrame
df = pd.read_csv(csv_file)

df

target_values = [
    'v41690973', 'v41690974', 'v41691050', 'v41691067', 'v41691108', 
    'v41691128', 'v41691153', 'v41691170', 'v41691206', 'v41691223', 
    'v41691224', 'v41691225'
]


# Use the 'loc' method to filter rows based on the 'vector' column
isolated_rows = df.loc[df['VECTOR'].isin(target_values)]
df=isolated_rows
isolated_rows

desired_columns = ['REF_DATE', 'Products and product groups', 'VALUE']

# Select and keep only the desired columns
selected_columns = df[desired_columns]
df=selected_columns
selected_columns
df.set_index('REF_DATE', inplace=True)
df

df.index = pd.to_datetime(df.index)
df = df.rename_axis('Date')
pivot_df = df.pivot_table(index='Date', columns='Products and product groups', values='VALUE')
df=pivot_df
#start_date = pd.Timestamp(pd.Timestamp.now().year - 1, 1, 1)
start_date = pd.Timestamp.now() - pd.DateOffset(months=12)
end_date = pd.Timestamp.now()

# Filter the DataFrame based on the date range
filtered_df = df.loc[start_date:end_date]
df_original=filtered_df
column_names_original=df_original.columns
df=filtered_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\clint\Desktop\Bank-of-canada-residuals-inflation\Untitled-1.ipynb Cell 1 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> csv_file = "18100004.csv"
#       <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> # Load the CSV file into a DataFrame
# ----> <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> df = pd.read_csv(csv_file)
#       <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> df
#      <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> target_values = [
#      <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a>     'v41690973', 'v41690974', 'v41691050', 'v41691067', 'v41691108',
#      <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W0sZmlsZQ%3D%3D?line=12'>13</a>     'v41691128', 'v41691153', 'v41691170', 'v41691206', 'v41691223',
#      <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W0sZmlsZQ%3D%3D?line=13'>14</a>     'v41691224', 'v41691225'
#      <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W0sZmlsZQ%3D%3D?line=14'>15</a> ]
#
# File c:\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Python310\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\Python310\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File c:\Python310\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File c:\Python310\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File c:\Python310\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '18100004.csv'

# %%
# Plot
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=6, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = df[df.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(df.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\clint\Desktop\Bank-of-canada-residuals-inflation\Untitled-1.ipynb Cell 2 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> fig, axes = plt.subplots(nrows=6, ncols=2, dpi=120, figsize=(10,6))
#       <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> for i, ax in enumerate(axes.flatten()):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a>     data = df[df.columns[i]]
#       <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a>     ax.plot(data, color='red', linewidth=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a>     # Decorations
#
# NameError: name 'df' is not defined

# %%
df_relative = df.div(df['All-items'], axis=0)
# Plot
df=df_relative
df.columns = ['Relative ' + column for column in df.columns]
df

fig, axes = plt.subplots(nrows=6, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = df[df.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(df.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\clint\Desktop\Bank-of-canada-residuals-inflation\Untitled-1.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> df_relative = df.div(df['All-items'], axis=0)
#       <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> # Plot
#       <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> df=df_relative
#
# NameError: name 'df' is not defined

# %%
#isolate relative food graph

df_relative_food = df[['Relative Food']]
df_relative_food
#graph df_relative_food
fig, axes = plt.subplots(nrows=1, ncols=1, dpi=120, figsize=(10,6))
data = df_relative_food[df_relative_food.columns[0]]
ax = axes
ax.plot(data, color='red', linewidth=1)
# Decorations
ax.set_title("Food CPI/Total CPI")
#ax.xaxis.set_ticks_position('none')
#ax.yaxis.set_ticks_position('none')
#ax.spines["top"].set_alpha(0)
#ax.tick_params(labelsize=6)

df_relative_food.to_csv('relative_food.csv', index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\clint\Desktop\Bank-of-canada-residuals-inflation\Untitled-1.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> #isolate relative food graph
# ----> <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> df_relative_food = df[['Relative Food']]
#       <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> df_relative_food
#       <a href='vscode-notebook-cell:/c%3A/Users/clint/Desktop/Bank-of-canada-residuals-inflation/Untitled-1.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> #graph df_relative_food
#
# NameError: name 'df' is not defined

# %%
df=filtered_df
df_inflation=filtered_df
for column in df.columns:
    if column != 'Date':
        df['Inflation '+column] = df[column].pct_change() * 100
df
# Drop NaN values
df.dropna(inplace=True)

# Drop the original columns
df.drop(columns=df.columns[0:12], inplace=True)
df

fig, axes = plt.subplots(nrows=6, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = df[df.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(df.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();
# Out:
# C:\Users\clint\AppData\Local\Temp\ipykernel_17392\3777890810.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Inflation '+column] = df[column].pct_change() * 100
# C:\Users\clint\AppData\Local\Temp\ipykernel_17392\3777890810.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Inflation '+column] = df[column].pct_change() * 100
# C:\Users\clint\AppData\Local\Temp\ipykernel_17392\3777890810.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Inflation '+column] = df[column].pct_change() * 100
# C:\Users\clint\AppData\Local\Temp\ipykernel_17392\3777890810.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Inflation '+column] = df[column].pct_change() * 100
# C:\Users\clint\AppData\Local\Temp\ipykernel_17392\3777890810.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Inflation '+column] = df[column].pct_change() * 100
# C:\Users\clint\AppData\Local\Temp\ipykernel_17392\3777890810.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Inflation '+column] = df[column].pct_change() * 100
# C:\Users\clint\AppData\Local\Temp\ipykernel_17392\3777890810.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Inflation '+column] = df[column].pct_change() * 100
# C:\Users\clint\AppData\Local\Temp\ipykernel_17392\3777890810.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Inflation '+column] = df[column].pct_change() * 100
# C:\Users\clint\AppData\Local\Temp\ipykernel_17392\3777890810.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Inflation '+column] = df[column].pct_change() * 100
# C:\Users\clint\AppData\Local\Temp\ipykernel_17392\3777890810.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Inflation '+column] = df[column].pct_change() * 100
# C:\Users\clint\AppData\Local\Temp\ipykernel_17392\3777890810.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Inflation '+column] = df[column].pct_change() * 100
# C:\Users\clint\AppData\Local\Temp\ipykernel_17392\3777890810.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Inflation '+column] = df[column].pct_change() * 100
# C:\Users\clint\AppData\Local\Temp\ipykernel_17392\3777890810.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
# C:\Users\clint\AppData\Local\Temp\ipykernel_17392\3777890810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=df.columns[0:12], inplace=True)

# %%
merged_df = pd.concat([df_relative.iloc[:, 0], df_inflation.iloc[:, 0]], axis=1)
merged_df = merged_df.dropna()
merged_df
df=merged_df
df['Time'] = range(len(df))
df
column_names = df.columns
from scipy.stats import linregress

# Calculate linear regression
slope, intercept, r_value, p_value, std_err = linregress(df[column_names[2]] * df[column_names[1]], df[column_names[0]]) #time*inflation, relative

# Calculate predicted values
predicted_values = slope * df[column_names[2]] * df[column_names[1]] + intercept #time*inflation

predicted_values
# Calculate residuals
df['Residuals '+ column_names_original[0]] = abs(df[column_names[0]] - predicted_values)
df


# Scatter plot of Time vs. Relative with Residuals
plt.scatter(df[column_names[2]]* df[column_names[1]], df[column_names[0]], label='Data')
plt.plot(df[column_names[2]]* df[column_names[1]], predicted_values, color='red', label='Regression Line')
plt.xlabel('Time')
plt.ylabel('Relative Price')
plt.title(column_names_original[0])
plt.legend()
plt.tight_layout()
plt.show()

df_initial_residuals = df.iloc[:, 3:]
df_residuals=df_initial_residuals

# %%
for x in range(1,12):
    merged_df = pd.concat([df_relative.iloc[:, x], df_inflation.iloc[:, x]], axis=1)
    merged_df = merged_df.dropna()
    merged_df
    df=merged_df
    df['Time'] = range(len(df))
    df
    column_names = df.columns
    df

    # Calculate linear regression
    slope, intercept, r_value, p_value, std_err = linregress(df[column_names[2]] * df[column_names[1]], df[column_names[0]]) #time*inflation, relative

    # Calculate predicted values
    predicted_values = slope * df[column_names[2]] * df[column_names[1]] + intercept #time*inflation

    # Calculate residuals
    df['Residuals '+ column_names_original[x]] = abs(df[column_names[0]] - predicted_values)


    # Scatter plot of Time vs. Relative with Residuals
    plt.scatter(df[column_names[2]]* df[column_names[1]], df[column_names[0]], label='Data')
    plt.plot(df[column_names[2]]* df[column_names[1]], predicted_values, color='red', label='Regression Line')
    plt.xlabel('Time')
    plt.ylabel('Relative Price')
    plt.title(column_names_original[x])
    plt.legend()
    plt.tight_layout()
    plt.show()

    df_current_residuals = df.iloc[:, 3:]
    df_current_residuals
    df_residuals = pd.merge(df_residuals, df_current_residuals, left_index=True, right_index=True)
    df_residuals

# %%
df=df_residuals
fig, axes = plt.subplots(nrows=6, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = df[df.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(df.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
df['Aggregate Residuals'] = df.sum(axis=1)

plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Aggregate Residuals'], marker='o', linestyle='-', color='b', label='Aggregate Residuals')
plt.title('Aggregate Residuals Over Time')
plt.xlabel('Date')
plt.ylabel('Aggregate Residuals')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Columns to sum
columns_to_sum = [
    'Residuals Clothing and footwear',
    'Residuals Household operations, furnishings and equipment',
    'Residuals Food'
]

# Sum the selected columns and create a new 'Aggregate Residuals' column
df['Food_Clothing_Household Residuals'] = df[columns_to_sum].sum(axis=1)



plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Food_Clothing_Household Residuals'], marker='o', linestyle='-', color='b', label='Aggregate Residuals')
plt.title('Food,Clothing,Household Residuals Over Time')
plt.xlabel('Date')
plt.ylabel('Residuals')
plt.legend()
plt.grid(True)
plt.show()
